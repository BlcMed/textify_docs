# %%
from textify_docs.document_converter import DocumentConverter

# %%
conveter = DocumentConverter()

# %%
pdf_path = 'documents/pdf.pdf'
pdf_text = conveter.convert_to_text(pdf_path)

# %%
print(pdf_text)
# Out:
# = adtaall
# ROYAUME DU MAROC Ne eet Usby
# MINISTERE DE L'INTERIEUR aelWyalg-e yam haa alge
#
# > CONSEIL DE LA REGION DRAA- TAFILALET Splaall Sagaas] Aggaall aldglt
#
# AGENCE REGIONALE D’'EXECUTION DES PROJETS oles x On tee cut
#
# Région Dr&a - Tafilalet
#
# EXTRAIT DU PROCES VERBAL
#
# D’APPEL D’OFFRES OUVERT SUR OFFRE DE PRIX N° 46/AREPDT/2024 relatif au Programme
# de la protection contre les incendies et aménagement et réhabilitation des Oasis de Draa
# Tafilalet : Travaux d’installation des poteaux d’incendie au niveau des communes Chourafae
# mdeghra, errteb, aoufous et Areb sebah ziz - Province d’Errachidia.
#
# Maitre d'ouvrage : Agence Régionale d’Exécution des Projets Dria-Tafilalet,
#
# * Date et heure d'ouverture des plis : 14/05/2024 4 11h00
# = Lieu d'ouverture des plis : Salle des réunions de ! AREP-DT.
# = Journaux ayant publié I'avis de publicité :
#
# e LE MATIN du 17/04/2024 ;
# e ASSAHRA AL MAGHRIBIA du 17/04/2024 ;
# ...

# %%
docx_path = 'documents/word docx.docx'
word_text = conveter.convert_to_text(docx_path)
print(word_text)
# Out:
#
#
#                             Résultat Définitif  A.O.O 16/RTTA/2024
#
# Objet de l’appel d’offre :
# Réalisation d’un audit énergétique du bâtiment de la Région
# Tanger-Tétouan-Al-Hoceima
#
#      Maitre d’ouvrage : Région  Tanger Tétouan  Al Hoceima
#
#
#
#
#
#
# Tanger le  04/06/2024
